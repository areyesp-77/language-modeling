# %% [markdown]
# # Más estructuras de control, más poder 💪💪💪
#
# Dejo fijo el [link](https://docs.python.org/es/3/tutorial/controlflow.html#) de la documentación de Python para acostumbrarnos a revisarla cada que tengamos que trabajar con datos, métodos, funciones o librerías nuevas.
#
# También les dejo [aquí](https://drive.google.com/file/d/1GSuDeFBR2oT-wnzM8bsDeldC0cIsqjNh/view) el material de referencia para reforzar contenidos.

# %% [markdown]
# ### Práctica (repaso de la sesión previa)
#
# * Convierte la siguiente STR en LIST
#   * 'El proyecto Ameresco (América y España español coloquial) surge de la mano de Antonio Briz como extensión natural del corpus Val.Es.Co. en 2010, con el fin de profundizar en el estudio de la variedad coloquial del español en geolectos europeos y americanos.  En el seno del proyecto Ameresco se han llevado a cabo iniciativas de investigación como la incorporación de usos americanos y americanismos en el Diccionario de Partículas Discursivas del Español (www.dpde.es), dirigido por Antonio Briz, Salvador Pons y José Portolés, o el estudio de la atenuación en todas las variedades del español, además de la iniciativa.'
#
# * Convierte todos los ítems a minúsculas
# * Usa el método .count ('WORD') para buscar cuántas veces aparece la palabra Ameresco en el corpus
# * Usa un for y un contador para obtener las frecuencias de todas las palabras de la LIST

# %%
texto = 'El proyecto Ameresco (América y España español coloquial) surge de la mano de Antonio Briz como extensión natural del corpus Val.Es.Co. en 2010, con el fin de profundizar en el estudio de la variedad coloquial del español en geolectos europeos y americanos.  En el seno del proyecto Ameresco se han llevado a cabo iniciativas de investigación como la incorporación de usos americanos y americanismos en el Diccionario de Partículas Discursivas del Español (www.dpde.es), dirigido por Antonio Briz, Salvador Pons y José Portolés, o el estudio de la atenuación en todas las variedades del español, además de la iniciativa.'

# %%
datos = texto.lower().split()
print(datos)

# %%
word1 = datos.count('proyecto')
print(word1)

# %%
#¿Cuántas veces aparece América en el corpus?

print('Ameresco aparece', word1, 'veces en el corpus')

#Hay que saber qué le pedimos a Python y qué es lo que devuelve

# %% [markdown]
# Ahora implementen este código y en el PRINT incorporen alguno de los métodos con los que hemos trabajado:
#
#
# ```
# word2 = datos.count('el')
# print(word2)
# ```

# %% [markdown]
# ##Usa un **for** y un contador para obtener las frecuencias de todas las palabras de la LIST

# %%
freq = 0
for i in datos:
    freq = datos.count(i)                    #cuando tiene el +, suma las frecuencias individuales, por eso el resultado es incorrecto
    print(i.capitalize(), ' | frecuencia =', freq)

# %% [markdown]
# #####Otra forma de obtener el mismo resultado, pero ahora combinando dos métodos.

# %%
frecuencia = []
for i in datos:
    frecuencia.append(datos.count(i))         #el método append añade elementos a LIST, por lo tanto, el registro es con []
    print(i, frecuencia[-1])

# %% [markdown]
# En el primer caso, se pueden hacer operaciones matemáticas porque el dato que se devuelve es un INT, en tanto que en el segundo, esto no se puede porque
# el dato devuelto es una secuencia.

# %%
freq1 = 0
for i in datos:
    freq1 = datos.count(i)
    x = i, freq1
print(len(x)/freq1)

# %%
#frecuencia1 = []
#for i in datos:
#    y = frecuencia1.append(datos.count(i))
#print(frecuencia1/len(y))

# %% [markdown]
# ## **Conclusión**: controlar el tipo de dato de origen y de salida para poder realizar los procesos que uno requiere

# %% [markdown]
# ## **If** y otras secuencias lógicas
#
#
#
#
# ```
# 'Prosody is the study of the tune and rhythm of speech and how these features contribute to meaning. Prosody is the study of those aspects of speech that typically apply to a level above that of the individual phoneme and very often to sequences of words (in prosodic phrases). Features above the level of the phoneme (or “segment”) are referred to as suprasegmentals.'
# ```

# %%
data = 'Prosody is the study of the tune and rhythm of speech and how these features contribute to meaning. Prosody is the study of those aspects of speech that typically apply to a level above that of the individual phoneme and very often to sequences of words (in prosodic phrases). Features above the level of the phoneme (or “segment”) are referred to as suprasegmentals.'
dataLower = data.lower().split()
print(dataLower)

# %%
# Búsqueda de un elemento en la lista
for i in dataLower:
    if 'study' in i:
        print(i.count(i))

# %%
# Búsqueda de elementos cuya longitud concuerde con la condición
for i in dataLower:
    if len(i) >= 6:
        print(i)

# %%
# Búsqueda de un elemento a partir de su frecuencia (método .count)
for i in dataLower:
    if i.count('study') >= 1:
        print(i.upper())

# %%
# Búsqueda excluyente
for i in dataLower:
    if 'the' in i:
        print('The word exists')
    else:
        print('The word does not exist')

# %%
# Ahora con la longitud:
for i in dataLower:
    if (len(i) >= 6):
        print(i.upper(), 'is bigger than 6 characters')
    else:
        print(i.upper(), 'is smaller than 6 characters')

# %% [markdown]
# ### Práctica
#
# * Tomen los mismos datos y hagan el código para que imprima
#   * 'Frequency REQUESTED', si la palabra tiene una frecuencia mayor/igual a 2
#   * 'Frequency not requested', de lo contrario.

# %%
contador = 0
for i in dataLower:
    contador = dataLower.count(i)
    if contador >= 2:
        print(i, '| frequency REQUESTED')
    else:
        print(i, '| frequency not requested')

# %% [markdown]
# ### Práctica
#
# * Tomen los mismos datos y hagan el código para que imprima
#   * 'Frequency REQUESTED', si la palabra tiene una frecuencia mayor/igual a 2
#   * 'Frequency not requested', de lo contrario.
#
# * Ahora modifiquen el código para que sólo las que tienen frecuencia igual a 2 sean las REQUESTED.

# %%
contador = 0
for i in dataLower:
    contador = dataLower.count(i)
    if contador == 2:
        print(i, '| frequency REQUESTED')
    else:
        print(i, '| frequency not requested')

# %% [markdown]
# ## Integrando el **elif**: dos condiciones excluyentes

# %%
contador2 = 0
for i in dataLower:
    contador2 = dataLower.count(i)
    if contador2 == 2:
        print(i, '| frequency REQUESTED')
    elif contador2 >= 2:
        print(i, '| frequency higher than expected')
    else:
        print(i, '| frequency not requested')

# %% [markdown]
# Otras formas de combinar estas secuencias
# * Un ejemplo traído del material de referencia
#   * ¿Cómo sería el código para quitar las vocales de un STR?
#     * 'she sells sea shells by the sea shore'

# %%
sentence = 'she sells sea shells by the sea shore'
vowels = 'aeiou'
newSentence = (''.join(vowel for vowel in sentence if vowel not in vowels))  #forma integrada para hacer varias tareas a la vez
print(newSentence)

# %% [markdown]
# Ahora implementen este código:
#
#
# ```
# sentence2 = sentence.split()
# out = ['sea']
# newSentence2 = (' '.join(v for v in sentence2 if v not in out))
# print(newSentence2)
# ```
#
# * ¿Qué es lo sucede y por qué?

# %%
sentence2 = sentence.split()
out = ['sea']
newSentence2 = (' '.join(v for v in sentence2 if v not in out))
print(newSentence2)

# %% [markdown]
# ### Práctica
#
# * Con base en el comportamiento anterior, hagan un código para eliminar las palabras funcionales del texto de **prosody**

# %%
prosody = 'Prosody is the study of the tune and rhythm of speech and how these features contribute to meaning. Prosody is the study of those aspects of speech that typically apply to a level above that of the individual phoneme and very often to sequences of words (in prosodic phrases). Features above the level of the phoneme (or “segment”) are referred to as suprasegmentals.'
prosodyLower = prosody.lower().split()
stoplist = ['of', 'the', 'in', 'a', 'an', 'with', 'and']
prosodyClean = (' '.join(word for word in prosodyLower if word not in stoplist))
print(prosodyClean)

# %% [markdown]
# ### Práctica
#
# * Con base en el comportamiento anterior, hagan un código para eliminar las palabras funcionales del texto de **prosody**
#
# * Modifiquen el código para eliminar los signos de puntuación

# %%
punctuation = '.,;:[]()$%'
prosodyClean2 = (''.join(punct for punct in prosodyClean if punct not in punctuation))
print(prosodyClean2)

# %% [markdown]
# ### Práctica
#
# * Con base en el comportamiento anterior, hagan un código para eliminar las palabras funcionales del texto de **prosody**
#
# * Modifiquen el código para eliminar los signos de puntuación
#
# * Hagan el código para contar la longitud de palabra para cada una de las palabras de **prosody**
#
# * Obtengan las frecuencias de todas las palabras y, por último, utilicen las secuencias de control para imprimir:
#   * Frequency of WORD = INT: accepted word, si las palabras tienen frecuencia igual a 2
#   * Frequency of WORD = INT >>> unexpected word, si ienen frecuencia mayor a 2
#   * Frequency of WORD = INT --- rejected word, de lo contrario

# %% [markdown]
# ## Un posible código para resolver la práctica es el siguiente:
#
#
#
# ```
# counter = 0
# prosodyClean3 = prosodyClean2.split()
# for i in prosodyClean3:
#     counter = prosodyClean3.count(i)
#     #print(i, counter)
#     if counter == 2:
#         print('Frequency of', i.upper(), '=', counter, ': accepted word')
#     elif counter >= 3:
#         print('Frequency of', i.upper(), '=', counter, '>>> unexpected word')
#     else:
#         print('Frequency of', i.upper(), '=', counter, ' --- rejected word')
# ```

# %% [markdown]
# ## Integración de tuplas
#
# Última secuencia: tuplas (dos elementos están relacionados {'a=1', 'b=2', 'c=3}.
#
# Los elementos en la tupla se insertan entre llaves {}. Las tuplas más comunes son los diccionarios.
#
# En este código vamos a crear un diccionario vacío para guardar los elementos de la lista junto con su frecuencia.
#
# Con ello, eliminaremos los tokens de nuestra representación y nos quedaremos con los types + su frecuencia (tokens).

# %%
frecuencia_dictionary = {}
for i in prosodyClean3:
    frecuencia_dictionary[i] = frecuencia_dictionary.get(i, 0) + 1
print(frecuencia_dictionary)

# %% [markdown]
# Ahora volvemos con las estructuras de control para extraer sólo las palabras con determinada frecuencia
#
# **Ojo** que aquí iteramos sobre el diccionario, no sobre la lista

# %%
for i, freqs in frecuencia_dictionary.items():
    #print(i, freqs)
    if freqs == 1:
        print(i, '=', freqs)
    #elif freqs in range(2, 3):
    else:
        print(i, '=', freqs, 'higher than expected')
